# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Keep an eye on your API usage. Use https://developers.google.com/maps/reporting/gmp-reporting as reference for how to monitor your usage and billing.
#
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os

# Import API key
from api_keys import g_key

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
city_DF = pd.read_csv('output/cities.csv')
city_DF.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    puerto ayora  -0.7393  -90.3518     69.78        85          91
# 1       busselton -33.6500  115.3333     60.04        68          93
# 2       cape town -33.9258   18.4232     62.10        78           0
# 3  saint-philippe -21.3585   55.7679     72.95        78          41
# 4         ushuaia -54.8000  -68.3000     49.66        40          20
#
#    Wind Speed Country        Date
# 0       12.68      EC  1634773921
# 1       15.61      AU  1634773921
# 2        3.00      ZA  1634773635
# 3       10.31      RE  1634773922
# 4       11.50      AR  1634773922

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
gmaps.configure(api_key=g_key)
locations = city_DF[["Lat", "Lng"]]
humidity = city_DF['Humidity']

# %%
fig = gmaps.figure()

heat_layer = gmaps.heatmap_layer(locations, weights=humidity, dissipating=False,
                                  max_intensity=300,
                                 point_radius = 3)

fig.add_layer(heat_layer)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
modCity_DF = city_DF.loc[city_DF['Max Temp']>70]
modCity_DF = modCity_DF.loc[modCity_DF['Max Temp']<80]
modCity_DF.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 3   saint-philippe -21.3585   55.7679     72.95        78          41
# 6          rikitea -23.1203 -134.9692     74.64        69          20
# 18      georgetown   5.4112  100.3354     76.93        94          40
# 25        beinamar   8.6698   15.3813     72.57        87         100
# 33          avarua -21.2078 -159.7750     77.05        65          75
#
#     Wind Speed Country        Date
# 3        10.31      RE  1634773922
# 6        21.18      PF  1634773665
# 18        5.01      MY  1634773926
# 25        3.15      TD  1634773928
# 33        9.22      CK  1634773931

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
params = {
    "location": "",
    'radius': 5000,
    "type": "hotel",
    'keyword':'hotel',
    "key": g_key,
}

hotel_df = pd.DataFrame(columns = ['Hotel Name','City','Country','Lat','Lng'])

for index, row in modCity_DF.iterrows():

    # add keyword to params dict
    lat = row['Lat']
    lng = row['Lng']
    params['location'] = f'{lat}, {lng}'
    
    City = row['City']
    
    
    # assemble url and make API request
    print(f"Retrieving Results for Index {index}: {City}.")
    response = requests.get(base_url, params=params).json()
    
    # extract results
    results = response['results']
    
    try:
        print(f"Closest Hotel is {results[0]['name']}.")
        hotel_df.loc[index, 'City'] = row['City']
        hotel_df.loc[index, 'Country'] = row['Country']
        hotel_df.loc[index, 'Hotel Name'] = results[0]['name']
        hotel_df.loc[index, 'Lat'] = results[0]['geometry']['location']['lat']
        hotel_df.loc[index, 'Lng'] = results[0]['geometry']['location']['lng']
        
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")
        
    print("------------")
# Out:
# Retrieving Results for Index 3: saint-philippe.
# Closest Hotel is Hôtel Les Embruns Du Baril.
# ------------
# Retrieving Results for Index 6: rikitea.
# Closest Hotel is Pension Bianca & Benoit.
# ------------
# Retrieving Results for Index 18: georgetown.
# Closest Hotel is Bayview Hotel Georgetown Penang.
# ------------
# Retrieving Results for Index 25: beinamar.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 33: avarua.
# Closest Hotel is The Islander Hotel.
# ------------
# Retrieving Results for Index 48: ponta do sol.
# Closest Hotel is Hotel do Campo.
# ------------
# Retrieving Results for Index 50: kiama.
# Closest Hotel is The Grand Hotel.
# ------------
# Retrieving Results for Index 56: ormara.
# Closest Hotel is Alqadri hotel zero point ormara.
# ------------
# Retrieving Results for Index 63: lubu.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 65: mahebourg.
# Closest Hotel is Shandrani Beachcomber Resort & Spa.
# ------------
# Retrieving Results for Index 66: atuona.
# Closest Hotel is Hôtel Hiva Oa Hanakee Lodge.
# ------------
# Retrieving Results for Index 69: kayes.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 82: flinders.
# Closest Hotel is Lakeview Hotel Motel.
# ------------
# Retrieving Results for Index 99: bela.
# Closest Hotel is Hotel Rajvilla.
# ------------
# Retrieving Results for Index 101: saint george.
# Closest Hotel is St. George Inn & Suites.
# ------------
# Retrieving Results for Index 102: bauchi.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 107: batemans bay.
# Closest Hotel is Quays Hotel.
# ------------
# Retrieving Results for Index 117: laguna.
# Closest Hotel is Hampton Inn & Suites Sacramento-Elk Grove Laguna I-5.
# ------------
# Retrieving Results for Index 118: saint-joseph.
# Closest Hotel is "Plantation Bed and Breakfast.
# ------------
# Retrieving Results for Index 124: piacabucu.
# Closest Hotel is Hotel Cara Peba.
# ------------
# Retrieving Results for Index 131: bambous virieux.
# Closest Hotel is La Hacienda Hotel.
# ------------
# Retrieving Results for Index 135: rajula.
# Closest Hotel is Hotel President.
# ------------
# Retrieving Results for Index 139: ranir bazar.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 143: bengkulu.
# Closest Hotel is Mercure Bengkulu.
# ------------
# Retrieving Results for Index 144: madimba.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 145: airai.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 149: chake chake.
# Closest Hotel is Hotel Archipelago.
# ------------
# Retrieving Results for Index 154: port-gentil.
# Closest Hotel is Hôtel L'Hirondelle.
# ------------
# Retrieving Results for Index 167: antsohihy.
# Closest Hotel is Hotel Tiako.
# ------------
# Retrieving Results for Index 169: camacha.
# Closest Hotel is Pestana Porto Santo.
# ------------
# Retrieving Results for Index 172: canyon.
# Closest Hotel is Holiday Inn Express & Suites Canyon, an IHG Hotel.
# ------------
# Retrieving Results for Index 183: lucea.
# Closest Hotel is Grand Palladium Jamaica Resort & Spa.
# ------------
# Retrieving Results for Index 187: tura.
# Closest Hotel is Hotel C&C.
# ------------
# Retrieving Results for Index 188: hambantota.
# Closest Hotel is The Peacock Beach Hotel Hambantota.
# ------------
# Retrieving Results for Index 191: lahij.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 195: tra vinh.
# Closest Hotel is Cuu Long Hotel.
# ------------
# Retrieving Results for Index 199: buraydah.
# Closest Hotel is Best Western Plus Buraidah.
# ------------
# Retrieving Results for Index 202: tefe.
# Closest Hotel is Stylos Hall Hotel.
# ------------
# Retrieving Results for Index 212: benguela.
# Closest Hotel is Hotel Luso.
# ------------
# Retrieving Results for Index 215: mitu.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 219: faanui.
# Closest Hotel is InterContinental Bora Bora Resort Thalasso Spa.
# ------------
# Retrieving Results for Index 228: bandarbeyla.
# Closest Hotel is JABIR HOTEL.
# ------------
# Retrieving Results for Index 230: riyadh.
# Closest Hotel is Radisson Blu Hotel, Riyadh.
# ------------
# Retrieving Results for Index 233: mogadishu.
# Closest Hotel is Jowhara International Hotel.
# ------------
# Retrieving Results for Index 236: axim.
# Closest Hotel is Lou Moon Resort - Eco Luxury.
# ------------
# Retrieving Results for Index 237: sao jose da coroa grande.
# Closest Hotel is Crôa Mares Hotel.
# ------------
# Retrieving Results for Index 242: caravelas.
# Closest Hotel is Pousada Liberdade.
# ------------
# Retrieving Results for Index 244: mbini.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 246: marzuq.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 251: maracacume.
# Closest Hotel is HOTEL MODELO.
# ------------
# Retrieving Results for Index 258: keelung.
# Closest Hotel is Evergreen Laurel Hotel (Keelung).
# ------------
# Retrieving Results for Index 262: santa marta.
# Closest Hotel is Hilton Garden Inn Santa Marta.
# ------------
# Retrieving Results for Index 265: tahta.
# Closest Hotel is أل مشعال.
# ------------
# Retrieving Results for Index 267: miri.
# Closest Hotel is Ajang Hotel.
# ------------
# Retrieving Results for Index 271: vera cruz.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 272: yaan.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 273: rundu.
# Closest Hotel is Hotel Rundu.
# ------------
# Retrieving Results for Index 276: lompoc.
# Closest Hotel is SureStay Plus Hotel By Best Western Lompoc.
# ------------
# Retrieving Results for Index 277: karratha.
# Closest Hotel is Karratha International Hotel.
# ------------
# Retrieving Results for Index 281: nouadhibou.
# Closest Hotel is HOTEL VALENCIA.
# ------------
# Retrieving Results for Index 293: george town.
# Closest Hotel is Bayview Hotel Georgetown Penang.
# ------------
# Retrieving Results for Index 298: juba.
# Closest Hotel is Pyramid Continental Hotel.
# ------------
# Retrieving Results for Index 300: sur.
# Closest Hotel is Al Ayjah Plaza Hotel.
# ------------
# Retrieving Results for Index 304: sokoni.
# Closest Hotel is Clove Island Zanzibar Villas & Spa.
# ------------
# Retrieving Results for Index 317: vao.
# Closest Hotel is OURE TERA beach resort.
# ------------
# Retrieving Results for Index 323: souillac.
# Closest Hotel is Shanti Maurice Resort & Spa.
# ------------
# Retrieving Results for Index 328: micheweni.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 330: saint-leu.
# Closest Hotel is Iloha Seaview Hotel.
# ------------
# Retrieving Results for Index 344: lethem.
# Closest Hotel is Hotel Takutu.
# ------------
# Retrieving Results for Index 345: itoman.
# Closest Hotel is Southern Beach Hotel & Resort Okinawa.
# ------------
# Retrieving Results for Index 348: sungairaya.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 355: edgewater.
# Closest Hotel is Best Western New Smyrna Beach Hotel & Suites.
# ------------
# Retrieving Results for Index 358: luanda.
# Closest Hotel is EPIC SANA Luanda.
# ------------
# Retrieving Results for Index 359: saint-pierre.
# Closest Hotel is Hôtel Le Saint-Pierre.
# ------------
# Retrieving Results for Index 366: khair.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 368: escarcega.
# Closest Hotel is HOTEL YAAKUNAH.
# ------------
# Retrieving Results for Index 372: quibor.
# Closest Hotel is Hostería Valle de Quibor.
# ------------
# Retrieving Results for Index 374: palm coast.
# Closest Hotel is Microtel Inn & Suites by Wyndham Palm Coast.
# ------------
# Retrieving Results for Index 376: san cristobal.
# Closest Hotel is Gran Hotel San Cristóbal Suite.
# ------------
# Retrieving Results for Index 378: quatre cocos.
# Closest Hotel is Constance Belle Mare Plage Mauritius.
# ------------
# Retrieving Results for Index 384: beira.
# Closest Hotel is Hotel Tivoli Beira.
# ------------
# Retrieving Results for Index 389: port blair.
# Closest Hotel is SeaShell, Port Blair.
# ------------
# Retrieving Results for Index 391: adamantina.
# Closest Hotel is Ipê Palace Hotel.
# ------------
# Retrieving Results for Index 394: jaisalmer.
# Closest Hotel is Shahi Palace Hotel.
# ------------
# Retrieving Results for Index 404: buta.
# Closest Hotel is HOTEL BISO NA BISO.
# ------------
# Retrieving Results for Index 406: bac lieu.
# Closest Hotel is Khách sạn Sài Gòn Bạc Liêu.
# ------------
# Retrieving Results for Index 410: maun.
# Closest Hotel is Cresta Riley's Hotel.
# ------------
# Retrieving Results for Index 419: shirgaon.
# Closest Hotel is LAXMI GARDEN BEACH RESORT.
# ------------
# Retrieving Results for Index 420: kuchinarai.
# Closest Hotel is Chatrudee parkview.
# ------------
# Retrieving Results for Index 447: libertador general san martin.
# Closest Hotel is Posada del Sol.
# ------------
# Retrieving Results for Index 450: ca mau.
# Closest Hotel is Phu Cuong Hotel - Ca Mau.
# ------------
# Retrieving Results for Index 453: nakhon phanom.
# Closest Hotel is ป่ายางรีสอร์ท.
# ------------
# Retrieving Results for Index 456: caxito.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 460: stabat.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 462: ruteng.
# Closest Hotel is Sky Flores Bungalow.
# ------------
# Retrieving Results for Index 466: grand-lahou.
# Closest Hotel is Hotel Beatitude de Grand Lahou.
# ------------
# Retrieving Results for Index 467: cordoba.
# Closest Hotel is Azur Real Hotel Boutique.
# ------------
# Retrieving Results for Index 468: tabou.
# Closest Hotel is hotêl doufoulougou.
# ------------
# Retrieving Results for Index 469: pangoa.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 471: muisne.
# Closest Hotel is Hotel Galapagos.
# ------------
# Retrieving Results for Index 474: belmonte.
# Closest Hotel is Pousada do Diogo.
# ------------
# Retrieving Results for Index 477: hobyo.
# Closest Hotel is Osmani Hotel.
# ------------
# Retrieving Results for Index 481: matadi.
# Closest Hotel is Hotel Vivi Palace.
# ------------
# Retrieving Results for Index 483: paragominas.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 487: tezu.
# Closest Hotel is Oshin Hotel.
# ------------
# Retrieving Results for Index 489: san-pedro.
# Closest Hotel is hotel residence christy.
# ------------
# Retrieving Results for Index 493: ndele.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 494: nicoya.
# Closest Hotel is Hotel El Regalo.
# ------------
# Retrieving Results for Index 495: puerto del rosario.
# Closest Hotel is Hotel El Mirador.
# ------------
# Retrieving Results for Index 498: cururupu.
# Closest Hotel is Hotel Cururupu.
# ------------
# Retrieving Results for Index 499: alice springs.
# Closest Hotel is DoubleTree by Hilton Hotel Alice Springs.
# ------------
# Retrieving Results for Index 500: port maria.
# Closest Hotel is Casa Maria Hotel.
# ------------
# Retrieving Results for Index 505: harper.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 506: salalah.
# Closest Hotel is Salalah Gardens Hotel.
# ------------
# Retrieving Results for Index 510: along.
# Closest Hotel is Hotel West.
# ------------
# Retrieving Results for Index 511: mattru.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 521: bonthe.
# Closest Hotel is Bonthe Holiday Village.
# ------------
# Retrieving Results for Index 527: progreso.
# Closest Hotel is Playa Linda Hotel.
# ------------
# Retrieving Results for Index 529: mindelo.
# Closest Hotel is Pont D'Agua Bohemian Chic Hotel.
# ------------
# Retrieving Results for Index 530: oron.
# Closest Hotel is Akos Hotel.
# ------------
# Retrieving Results for Index 531: takoradi.
# Closest Hotel is Best Western Plus Atlantic Hotel.
# ------------
# Retrieving Results for Index 533: kinshasa.
# Closest Hotel is Béatrice Hotel.
# ------------
# Retrieving Results for Index 548: tevaitoa.
# Closest Hotel is Hôtel Raiatea Lodge.
# ------------
# Retrieving Results for Index 557: purificacion.
# Closest Hotel is Hotel Villa de las Palmas.
# ------------
# Retrieving Results for Index 558: zaraza.
# Closest Hotel is Hotel Adan Suites.
# ------------
# Retrieving Results for Index 559: umm lajj.
# Closest Hotel is Juman Hotel.
# ------------
# Retrieving Results for Index 561: chhapar.
# Closest Hotel is Tal Chhapar Forest Rest House.
# ------------
# Retrieving Results for Index 563: ewo.
# Closest Hotel is Hotel Oka.
# ------------
# Retrieving Results for Index 565: awbari.
# Closest Hotel is فندق أوباري.
# ------------
# Retrieving Results for Index 566: chino valley.
# Closest Hotel is Days Inn by Wyndham Chino Valley.
# ------------
# Retrieving Results for Index 574: carutapera.
# Closest Hotel is HOTEL R. SOARES.
# ------------
# Retrieving Results for Index 576: awjilah.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 581: manavalakurichi.
# Closest Hotel is THE HOTEL PARK COLACHEL.
# ------------
# Retrieving Results for Index 582: itarema.
# Closest Hotel is Vila Ybytu Eco Resort.
# ------------
# Retrieving Results for Index 584: tuy hoa.
# Closest Hotel is Sala TuyHoa Beach Hotel.
# ------------
# Retrieving Results for Index 585: marovoay.
# Closest Hotel is Hôtel 5/5 Marovoay.
# ------------
# Retrieving Results for Index 590: comodoro rivadavia.
# Closest Hotel is Hotel Playa.
# ------------
# Retrieving Results for Index 596: eyl.
# Closest Hotel is Amiin Hotel.
# ------------

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Lat", "Lng"]]

# %%
# Add marker layer ontop of heat map

# Display figure
markers = gmaps.marker_layer(locations, info_box_content= hotel_info)
fig.add_layer(markers)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
